# %%
import pandas as pd

df = pd.read_csv('train.csv')
df.info #informacion de la tabla

dep = df[df['ESTU_PRGM_DEPARTAMENTO']=='ANTIOQUIA'] #Filtración por departamento
dep
# Out:
#             ID  PERIODO                  ESTU_PRGM_ACADEMICO  \
# 4       989032    20212                           PSICOLOGIA
# 5       659872    20203                 MEDICINA VETERINARIA
# 9       465511    20183           ADMINISTRACION DE EMPRESAS
# 18      797253    20183                     CIENCIA POLITICA
# 28      240296    20183                     INGENIERIA CIVIL
# ...        ...      ...                                  ...
# 692440  237810    20203                             FINANZAS
# 692456  344635    20212                   CONTADURIA PUBLICA
# 692459  279065    20183  BACTERIOLOGIA Y LABORATORIO CLINICO
# 692466  372690    20183                   CONTADURIA PUBLICA
# 692499  933374    20195                           PSICOLOGIA
#
#        ESTU_PRGM_DEPARTAMENTO            ESTU_VALORMATRICULAUNIVERSIDAD  \
# 4                   ANTIOQUIA  Entre 2.5 millones y menos de 4 millones
# 5                   ANTIOQUIA                         Más de 7 millones
# 9                   ANTIOQUIA  Entre 2.5 millones y menos de 4 millones
# 18                  ANTIOQUIA                          Menos de 500 mil
# 28                  ANTIOQUIA  Entre 5.5 millones y menos de 7 millones
# ...                       ...                                       ...
# 692440              ANTIOQUIA                         Más de 7 millones
# 692456              ANTIOQUIA  Entre 4 millones y menos de 5.5 millones
# 692459              ANTIOQUIA    Entre 1 millón y menos de 2.5 millones
# 692466              ANTIOQUIA    Entre 1 millón y menos de 2.5 millones
# 692499              ANTIOQUIA  Entre 5.5 millones y menos de 7 millones
#
#        ESTU_HORASSEMANATRABAJA FAMI_ESTRATOVIVIENDA FAMI_TIENEINTERNET  \
# 4          Entre 21 y 30 horas            Estrato 3                 Si
# 5            Menos de 10 horas            Estrato 5                 Si
# 9              Más de 30 horas            Estrato 5                 Si
# 18             Más de 30 horas            Estrato 1                 No
# 28             Más de 30 horas            Estrato 3                 Si
# ...                        ...                  ...                ...
# 692440                       0            Estrato 6                 Si
# 692456     Entre 21 y 30 horas            Estrato 5                 No
# 692459       Menos de 10 horas            Estrato 3                 Si
# 692466     Entre 11 y 20 horas            Estrato 3                 Si
# 692499         Más de 30 horas            Estrato 4                 Si
#
#                          FAMI_EDUCACIONPADRE FAMI_TIENELAVADORA  ...  \
# 4                          Primaria completa                 Si  ...
# 5             Educación profesional completa                 Si  ...
# 9                                  Postgrado                 Si  ...
# 18                       Primaria incompleta                 No  ...
# 28      Secundaria (Bachillerato) incompleta                 Si  ...
# ...                                      ...                ...  ...
# 692440        Educación profesional completa                 Si  ...
# 692456        Educación profesional completa                 Si  ...
# 692459        Técnica o tecnológica completa                 Si  ...
# 692466                   Primaria incompleta                 Si  ...
# 692499    Secundaria (Bachillerato) completa                 Si  ...
#
#        ESTU_PRIVADO_LIBERTAD ESTU_PAGOMATRICULAPROPIO FAMI_TIENECOMPUTADOR  \
# 4                          N                       No                   Si
# 5                          N                       No                   Si
# 9                          N                       Si                   Si
# 18                         N                       Si                   Si
# 28                         N                       No                   Si
# ...                      ...                      ...                  ...
# 692440                     N                       No                   Si
# 692456                     N                       Si                   Si
# 692459                     N                       No                   Si
# 692466                     N                       No                   Si
# 692499                     N                       No                   Si
#
#        FAMI_TIENEINTERNET.1                   FAMI_EDUCACIONMADRE  \
# 4                        Si                     Primaria completa
# 5                        Si    Secundaria (Bachillerato) completa
# 9                        Si                             Postgrado
# 18                       No                   Primaria incompleta
# 28                       Si  Secundaria (Bachillerato) incompleta
# ...                     ...                                   ...
# 692440                   Si        Educación profesional completa
# 692456                   No  Secundaria (Bachillerato) incompleta
# 692459                   Si        Técnica o tecnológica completa
# 692466                   Si                     Primaria completa
# 692499                   Si        Técnica o tecnológica completa
#
#        RENDIMIENTO_GLOBAL coef_1  coef_2  coef_3  coef_4
# 4              medio-bajo  0.316   0.232   0.285   0.294
# 5              medio-alto  0.553   0.142   0.248   0.175
# 9                    alto  0.535   0.122   0.257   0.167
# 18                   alto  0.153   0.388   0.217   0.287
# 28             medio-alto  0.312   0.229   0.302   0.248
# ...                   ...    ...     ...     ...     ...
# 692440         medio-alto  0.645   0.151   0.186   0.114
# 692456               bajo  0.574   0.119   0.233   0.161
# 692459         medio-alto  0.323   0.237   0.305   0.285
# 692466         medio-bajo  0.284   0.234   0.295   0.256
# 692499               alto  0.487   0.180   0.251   0.187
#
# [83607 rows x 21 columns]
