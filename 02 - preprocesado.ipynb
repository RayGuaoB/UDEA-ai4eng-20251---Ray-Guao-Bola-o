# %%
import os
os.chdir("C:\\Users\\lopez\\Desktop\\udea-ai-4-eng-20251-pruebas-saber-pro-colombia") # Ruta donde se encuentra la carpeta con los archivos
os.listdir()
# Out:
# ['submission_example.csv', 'test.csv', 'train.csv']

# %%
import pandas as pd
df = pd.read_csv("train.csv")
df.info()
df.shape
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 692500 entries, 0 to 692499
# Data columns (total 21 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   ID                              692500 non-null  int64
#  1   PERIODO                         692500 non-null  int64
#  2   ESTU_PRGM_ACADEMICO             692500 non-null  object
#  3   ESTU_PRGM_DEPARTAMENTO          692500 non-null  object
#  4   ESTU_VALORMATRICULAUNIVERSIDAD  686213 non-null  object
#  5   ESTU_HORASSEMANATRABAJA         661643 non-null  object
#  6   FAMI_ESTRATOVIVIENDA            660363 non-null  object
#  7   FAMI_TIENEINTERNET              665871 non-null  object
#  8   FAMI_EDUCACIONPADRE             669322 non-null  object
#  9   FAMI_TIENELAVADORA              652727 non-null  object
#  10  FAMI_TIENEAUTOMOVIL             648877 non-null  object
#  11  ESTU_PRIVADO_LIBERTAD           692500 non-null  object
# ...

# %%
df.head(10)
# Out:
#        ID  PERIODO                  ESTU_PRGM_ACADEMICO  \
# 0  904256    20212                           ENFERMERIA
# 1  645256    20212                              DERECHO
# 2  308367    20203                MERCADEO Y PUBLICIDAD
# 3  470353    20195           ADMINISTRACION DE EMPRESAS
# 4  989032    20212                           PSICOLOGIA
# 5  659872    20203                 MEDICINA VETERINARIA
# 6   47159    20183                  INGENIERIA MECANICA
# 7   11829    20183  ADMINISTRACIÓN EN SALUD OCUPACIONAL
# 8  257869    20212                INGENIERIA INDUSTRIAL
# 9  465511    20183           ADMINISTRACION DE EMPRESAS
#
#   ESTU_PRGM_DEPARTAMENTO            ESTU_VALORMATRICULAUNIVERSIDAD  \
# 0                 BOGOTÁ  Entre 5.5 millones y menos de 7 millones
# 1              ATLANTICO  Entre 2.5 millones y menos de 4 millones
# 2                 BOGOTÁ  Entre 2.5 millones y menos de 4 millones
# 3              SANTANDER  Entre 4 millones y menos de 5.5 millones
# ...

# %% [markdown]
# # Rellenar valores null en la columna

# %% [markdown]
# Primero verificamos los valores null

# %%
print(df.isnull().sum()) # Verificacion numerica de valores null en toda la tabla

df[df["FAMI_ESTRATOVIVIENDA"].isnull()] # verificacion en tabla de valores null FAMI_ESTRATOVIVIENDA
# Out:
# ID                                    0
# PERIODO                               0
# ESTU_PRGM_ACADEMICO                   0
# ESTU_PRGM_DEPARTAMENTO                0
# ESTU_VALORMATRICULAUNIVERSIDAD     6287
# ESTU_HORASSEMANATRABAJA           30857
# FAMI_ESTRATOVIVIENDA              32137
# FAMI_TIENEINTERNET                26629
# FAMI_EDUCACIONPADRE               23178
# FAMI_TIENELAVADORA                39773
# FAMI_TIENEAUTOMOVIL               43623
# ESTU_PRIVADO_LIBERTAD                 0
# ESTU_PAGOMATRICULAPROPIO           6498
# FAMI_TIENECOMPUTADOR              38103
# FAMI_TIENEINTERNET.1              26629
# FAMI_EDUCACIONMADRE               23664
# RENDIMIENTO_GLOBAL                    0
# coef_1                                0
# coef_2                                0
# coef_3                                0
# coef_4                                0
# dtype: int64
#             ID  PERIODO                 ESTU_PRGM_ACADEMICO  \
# ...

# %% [markdown]
# Se observa que tenemos 32137 valores null para la columna FAMI_ESTRATOVIVIENDA

# %%
df["FAMI_ESTRATOVIVIENDA"].unique() #Valores en columna
# Out:
# array(['Estrato 3', 'Estrato 4', 'Estrato 5', 'Estrato 2', 'Estrato 1',
#        nan, 'Estrato 6', 'Sin Estrato'], dtype=object)

# %%
df['FAMI_ESTRATOVIVIENDA'].head(50)
# Out:
# 0     Estrato 3
# 1     Estrato 3
# 2     Estrato 3
# 3     Estrato 4
# 4     Estrato 3
# 5     Estrato 5
# 6     Estrato 2
# 7     Estrato 2
# 8     Estrato 1
# 9     Estrato 5
# 10    Estrato 1
# 11    Estrato 2
# 12    Estrato 3
# 13    Estrato 1
# 14    Estrato 3
# 15    Estrato 3
# 16    Estrato 1
# 17    Estrato 2
# 18    Estrato 1
# 19    Estrato 2
# 20    Estrato 2
# 21          NaN
# 22    Estrato 1
# 23    Estrato 2
# 24    Estrato 2
# 25    Estrato 3
# 26          NaN
# 27    Estrato 3
# 28    Estrato 3
# 29    Estrato 2
# 30    Estrato 2
# 31    Estrato 3
# 32    Estrato 2
# 33    Estrato 3
# 34    Estrato 4
# 35    Estrato 3
# 36    Estrato 4
# 37    Estrato 2
# 38    Estrato 2
# 39    Estrato 2
# 40    Estrato 4
# 41    Estrato 3
# 42    Estrato 2
# 43    Estrato 1
# 44    Estrato 2
# 45    Estrato 3
# 46    Estrato 2
# 47    Estrato 3
# 48    Estrato 3
# 49          NaN
# Name: FAMI_ESTRATOVIVIENDA, dtype: object

# %% [markdown]
# Rellenamos los valores null de acuerdo a la moda, ya que es un valor categorico

# %%
df['FAMI_ESTRATOVIVIENDA'] = df['FAMI_ESTRATOVIVIENDA'].fillna(df['FAMI_ESTRATOVIVIENDA'].mode()[0]) # Rellenamos los valores null con la moda

df['FAMI_ESTRATOVIVIENDA'].head(50)
# Out:
# 0     Estrato 3
# 1     Estrato 3
# 2     Estrato 3
# 3     Estrato 4
# 4     Estrato 3
# 5     Estrato 5
# 6     Estrato 2
# 7     Estrato 2
# 8     Estrato 1
# 9     Estrato 5
# 10    Estrato 1
# 11    Estrato 2
# 12    Estrato 3
# 13    Estrato 1
# 14    Estrato 3
# 15    Estrato 3
# 16    Estrato 1
# 17    Estrato 2
# 18    Estrato 1
# 19    Estrato 2
# 20    Estrato 2
# 21    Estrato 2
# 22    Estrato 1
# 23    Estrato 2
# 24    Estrato 2
# 25    Estrato 3
# 26    Estrato 2
# 27    Estrato 3
# 28    Estrato 3
# 29    Estrato 2
# 30    Estrato 2
# 31    Estrato 3
# 32    Estrato 2
# 33    Estrato 3
# 34    Estrato 4
# 35    Estrato 3
# 36    Estrato 4
# 37    Estrato 2
# 38    Estrato 2
# 39    Estrato 2
# 40    Estrato 4
# 41    Estrato 3
# 42    Estrato 2
# 43    Estrato 1
# 44    Estrato 2
# 45    Estrato 3
# 46    Estrato 2
# 47    Estrato 3
# 48    Estrato 3
# 49    Estrato 2
# Name: FAMI_ESTRATOVIVIENDA, dtype: object

# %% [markdown]
# Finalmente podemos observar que en los valores 21 y 49 que anteriormente eran valores null, ahora tienen valores de acuerdo a la moda

# %%
print(df.isnull().sum())
# Out:
# ID                                    0
# PERIODO                               0
# ESTU_PRGM_ACADEMICO                   0
# ESTU_PRGM_DEPARTAMENTO                0
# ESTU_VALORMATRICULAUNIVERSIDAD     6287
# ESTU_HORASSEMANATRABAJA           30857
# FAMI_ESTRATOVIVIENDA                  0
# FAMI_TIENEINTERNET                26629
# FAMI_EDUCACIONPADRE               23178
# FAMI_TIENELAVADORA                39773
# FAMI_TIENEAUTOMOVIL               43623
# ESTU_PRIVADO_LIBERTAD                 0
# ESTU_PAGOMATRICULAPROPIO           6498
# FAMI_TIENECOMPUTADOR              38103
# FAMI_TIENEINTERNET.1              26629
# FAMI_EDUCACIONMADRE               23664
# RENDIMIENTO_GLOBAL                    0
# coef_1                                0
# coef_2                                0
# coef_3                                0
# coef_4                                0
# FAMI_ESTRATOVIVIENDA_encoded          0
# dtype: int64

# %% [markdown]
# # Codificación Columna FAMI_ESTRATOVIVIENDA (One-Hot Encoding)

# %%
df["FAMI_ESTRATOVIVIENDA"].unique() #Valores en columna
# Out:
# array(['Estrato 3', 'Estrato 4', 'Estrato 5', 'Estrato 2', 'Estrato 1',
#        'Estrato 6', 'Sin Estrato'], dtype=object)

# %%
df["FAMI_ESTRATOVIVIENDA_encoded"] = pd.Categorical(
    df["FAMI_ESTRATOVIVIENDA"],
    categories=["Sin Estrato", "Estrato 1", "Estrato 2", "Estrato 3", "Estrato 4", "Estrato 5", "Estrato 6"],
    ordered=True,
).codes

df[["FAMI_ESTRATOVIVIENDA", "FAMI_ESTRATOVIVIENDA_encoded"]].drop_duplicates().sort_values("FAMI_ESTRATOVIVIENDA_encoded")
# Out:
#     FAMI_ESTRATOVIVIENDA  FAMI_ESTRATOVIVIENDA_encoded
# 176          Sin Estrato                             0
# 8              Estrato 1                             1
# 6              Estrato 2                             2
# 0              Estrato 3                             3
# 3              Estrato 4                             4
# 5              Estrato 5                             5
# 154            Estrato 6                             6
